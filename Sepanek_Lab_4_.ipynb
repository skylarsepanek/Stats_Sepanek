# %% [markdown]
# <a href="https://colab.research.google.com/github/skylarsepanek/Stats_Sepanek/blob/main/Sepanek_Lab_4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from skimage.io import imread 
from skimage.transform import resize

# %%
url = 'https://raw.githubusercontent.com/skylarsepanek/Stats_Sepanek/main/dunkin/1.jpg' #image url

# %%
im = imread(url)

# %%
im.shape #the shape of my image
# Out:
# (225, 225, 3)

# %%
im_flattened = im.reshape(-1)

# %%
plt.figure(figsize=(10,5)).  #imput image
plt.imshow(im);
plt.axis('off');

# %%
plt.plot(im_flattened) #pixels of my image

# %%
im_flattened[0:10]
# Out:
# array([255, 255, 255, 255, 255, 255, 255, 255, 255, 255], dtype=uint8)

# %%
plt.imshow(im);

# %%
im.shape
# Out:
# (225, 225, 3)

# %%
plt.imshow(im[:,:,0],cmap='gray') #made black and white image

# %%
plt.imshow(im[0:50,100:200,:]) #cropped picture
